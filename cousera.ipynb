# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Sindhu__ <br>
# Student

# %% [markdown]
# _I have a deep interest in the field of Data Science. I often read the popular blogs like Towards Data Science etc. However I feel I lack the understanding of the basics of Data Science and hence I am not able to comprehend the articles very well. So I want to do a course that covers the fundamental topics of this field._

# %% [markdown]
# ### Addition of two numbers

# %%
1+1
# Out:
# 2

# %% [markdown]
# [click me](https://www.coursera.org/learn/open-source-tools-for-data-science/ungradedWidget/c1F5I/instructions-create-and-share-your-jupyter-notebook)<br>
# <strike>not me</strike><br>
# <blockquote>
# <p>This is a blockquote.</p>
# <p>This is part of the same blockquote.</p>
# </blockquote>
# <p>Quote break</p>
# <blockquote>
# <p>This is a new blockquote.</p>
# </blockquote>
